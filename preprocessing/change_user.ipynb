# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
file_path = 'C:\\Users\\ljy25\\etri\\data\\user01-06\\user01-06'
user_list = os.listdir('C:\\Users\\ljy25\\etri\\data\\user01-06\\user01-06')
print("user_list : ", user_list)

user06_path = file_path + '\\' + user_list[5]
user06 = os.listdir(user06_path)
print("user06 : ", user06)
# Out:
# user_list :  ['user01', 'user02', 'user03', 'user04', 'user05', 'user06']
# user06 :  ['1599757200', '1599836400', '1599922800', '1600009200', '1600095600', '1600215480', '1600304580', '1600389540', '1600441200', '1600529340', '1600614000', '1600734060', '1600814040', '1600907880', '1600959600', '1601046000', '1601179860', '1601218800', '1601305200', '1601391600', '1601478000', '1601564400', '1601650800', '1601737200', '1601823600', '1601912160', '1601996400', '1602082800']

# %%
# df 이면 dt.tz_localize , dt.tz_convert
print("utc : ", pd.to_datetime(user06, unit='s').tz_localize('UTC').tz_convert('Asia/Seoul'))
# Out:
# utc :  DatetimeIndex(['2020-09-11 01:59:44+09:00', '2020-09-12 00:00:16+09:00',
#                '2020-09-13 00:00:16+09:00', '2020-09-14 00:00:16+09:00',
#                '2020-09-15 00:00:16+09:00', '2020-09-16 09:17:04+09:00',
#                '2020-09-17 10:04:00+09:00', '2020-09-18 09:38:24+09:00',
#                '2020-09-19 00:00:16+09:00', '2020-09-20 00:28:00+09:00',
#                '2020-09-21 00:00:16+09:00', '2020-09-22 09:21:20+09:00',
#                '2020-09-23 07:34:40+09:00', '2020-09-24 09:38:24+09:00',
#                '2020-09-25 00:00:16+09:00', '2020-09-26 00:00:16+09:00',
#                '2020-09-27 13:11:44+09:00', '2020-09-28 00:00:16+09:00',
#                '2020-09-29 00:00:16+09:00', '2020-09-30 00:00:16+09:00',
#                '2020-10-01 00:00:16+09:00', '2020-10-02 00:00:16+09:00',
#                '2020-10-03 00:00:16+09:00', '2020-10-04 00:00:16+09:00',
#                '2020-10-05 00:00:16+09:00', '2020-10-06 00:36:32+09:00',
# ...

# %%
user06_1_path = (user06_path + '\\' + user06[0])
user06_1 = os.listdir(user06_1_path)
print("user06_1 : ", user06_1 )

user06_1_e4Acc_path = user06_1_path + '\\' + user06_1[1]
user06_1_e4Acc = os.listdir(user06_1_e4Acc_path)
print("user06_1_e4Acc : ", user06_1_e4Acc)
# Out:
# user06_1 :  ['1599757200_label.csv', 'e4Acc', 'e4Bvp', 'e4Eda', 'e4Hr', 'e4Temp', 'mAcc', 'mGps', 'mGyr', 'mMag']
# ...

# %%
# label
user06_1_label_path = user06_1_path + '\\' + user06_1[0]
user06_1_label = pd.read_csv(user06_1_label_path)
user06_1_label
# Out:
#                ts       action  actionOption actionSub  actionSubOption  \
# 0    1.599757e+09        sleep           111       NaN              NaN
# 1    1.599757e+09        sleep           111       NaN              NaN
# 2    1.599757e+09        sleep           111       NaN              NaN
# 3    1.599757e+09        sleep           111       NaN              NaN
# 4    1.599757e+09        sleep           111       NaN              NaN
# ..            ...          ...           ...       ...              ...
# 913  1.599834e+09  socialising           711       NaN              NaN
# 914  1.599834e+09  socialising           711       NaN              NaN
# 915  1.599834e+09  socialising           711       NaN              NaN
# 916  1.599834e+09  socialising           711       NaN              NaN
# 917  1.599834e+09  socialising           711       NaN              NaN
#
#      condition  conditionSub1Option  conditionSub2Option place  \
# ...

# %%
user06_1_label['ts'] = pd.to_datetime(user06_1_label['ts'], unit='s').dt.tz_localize('UTC').dt.tz_convert('Asia/Seoul') 
user06_1_label
# Out:
#                            ts       action  actionOption actionSub  \
# 0   2020-09-11 02:00:00+09:00        sleep           111       NaN
# 1   2020-09-11 02:01:00+09:00        sleep           111       NaN
# 2   2020-09-11 02:02:00+09:00        sleep           111       NaN
# 3   2020-09-11 02:03:00+09:00        sleep           111       NaN
# 4   2020-09-11 02:04:00+09:00        sleep           111       NaN
# ..                        ...          ...           ...       ...
# 913 2020-09-11 23:15:00+09:00  socialising           711       NaN
# 914 2020-09-11 23:16:00+09:00  socialising           711       NaN
# 915 2020-09-11 23:17:00+09:00  socialising           711       NaN
# 916 2020-09-11 23:18:00+09:00  socialising           711       NaN
# 917 2020-09-11 23:19:00+09:00  socialising           711       NaN
#
#      actionSubOption  condition  conditionSub1Option  conditionSub2Option  \
# 0                NaN   WITH_ONE                  1.0                  1.0
# ...

# %%
user06_1_label['ts'] = user06_1_label['ts'].dt.strftime('%Y-%m-%d %H:%M')
user06_1_label
# Out:
#                    ts       action  actionOption actionSub  actionSubOption  \
# 0    2020-09-11 02:00        sleep           111       NaN              NaN
# 1    2020-09-11 02:01        sleep           111       NaN              NaN
# 2    2020-09-11 02:02        sleep           111       NaN              NaN
# 3    2020-09-11 02:03        sleep           111       NaN              NaN
# 4    2020-09-11 02:04        sleep           111       NaN              NaN
# ..                ...          ...           ...       ...              ...
# 913  2020-09-11 23:15  socialising           711       NaN              NaN
# 914  2020-09-11 23:16  socialising           711       NaN              NaN
# 915  2020-09-11 23:17  socialising           711       NaN              NaN
# 916  2020-09-11 23:18  socialising           711       NaN              NaN
# 917  2020-09-11 23:19  socialising           711       NaN              NaN
#
# ...

# %%
user06_1_label['time'] = user06_1_label['ts'].apply(lambda x : x[11:])
user06_1_label
# Out:
#                    ts       action  actionOption actionSub  actionSubOption  \
# 0    2020-09-11 02:00        sleep           111       NaN              NaN
# 1    2020-09-11 02:01        sleep           111       NaN              NaN
# 2    2020-09-11 02:02        sleep           111       NaN              NaN
# 3    2020-09-11 02:03        sleep           111       NaN              NaN
# 4    2020-09-11 02:04        sleep           111       NaN              NaN
# ..                ...          ...           ...       ...              ...
# 913  2020-09-11 23:15  socialising           711       NaN              NaN
# 914  2020-09-11 23:16  socialising           711       NaN              NaN
# 915  2020-09-11 23:17  socialising           711       NaN              NaN
# 916  2020-09-11 23:18  socialising           711       NaN              NaN
# 917  2020-09-11 23:19  socialising           711       NaN              NaN
#
# ...

# %%
i = 700
print(user06_1_label['time'][i])
print(user06_1_label['action'][i])
# Out:
# 19:42
# meal

# %%
user06_1_label['action'].value_counts()
# Out:
# action
# work                367
# recreation_media    196
# sleep               108
# travel               75
# socialising          75
# personal_care        60
# meal                 29
# recreation_etc        8
# Name: count, dtype: int64

# %%
plt.scatter(user06_1_label['time'], user06_1_label['action'])
plt.scatter(user06_1_label['time'], user06_1_label['condition'])
plt.scatter(user06_1_label['time'], user06_1_label['place'])

# %%
# e4ACC
user06_1_e4Acc_1_path = user06_1_e4Acc_path + '\\' + user06_1_e4Acc[0]
user06_1_e4Acc_1 = pd.read_csv(user06_1_e4Acc_1_path)
user06_1_e4Acc_1
# Out:
#       timestamp         x         y         z
# 0        13.000 -0.171875 -0.718750  0.515625
# 1        13.031 -0.109375 -0.734375  0.515625
# 2        13.062 -0.031250 -0.734375  0.515625
# 3        13.093  0.031250 -0.765625  0.468750
# 4        13.125  0.046875 -0.796875  0.437500
# ...         ...       ...       ...       ...
# 1499     59.843 -0.265625  0.953125 -0.140625
# 1500     59.875 -0.296875  0.968750 -0.156250
# 1501     59.906 -0.343750  0.968750 -0.187500
# 1502     59.937 -0.328125  1.000000 -0.171875
# 1503     59.968 -0.296875  1.000000 -0.187500
#
# [1504 rows x 4 columns]

# %%
user06_1_e4Acc_1_path = user06_1_e4Acc_path + '\\' + user06_1_e4Acc[739]
user06_1_e4Acc_1 = pd.read_csv(user06_1_e4Acc_1_path)
user06_1_e4Acc_1
# Out:
#       timestamp         x         y         z
# 0         0.000  0.625000 -0.734375 -0.015625
# 1         0.031  0.625000 -0.750000 -0.031250
# 2         0.062  0.625000 -0.734375 -0.031250
# 3         0.093  0.625000 -0.734375 -0.031250
# 4         0.125  0.593750 -0.734375 -0.031250
# ...         ...       ...       ...       ...
# 1249     39.031 -0.671875 -0.515625  0.546875
# 1250     39.062 -0.640625 -0.515625  0.546875
# 1251     39.093 -0.671875 -0.515625  0.562500
# 1252     39.125 -0.671875 -0.515625  0.562500
# 1253     39.156 -0.671875 -0.515625  0.562500
#
# [1254 rows x 4 columns]

# %%
user06_1_e4Acc_1_path = user06_1_e4Acc_path + '\\' + user06_1_e4Acc[1]
user06_1_e4Acc_1 = pd.read_csv(user06_1_e4Acc_1_path)
user06_1_e4Acc_1
# Out:
#       timestamp         x         y         z
# 0         0.000 -0.250000  0.953125 -0.171875
# 1         0.031 -0.218750  0.968750 -0.140625
# 2         0.062 -0.203125  0.953125 -0.109375
# 3         0.093 -0.265625  0.953125 -0.125000
# 4         0.125 -0.312500  0.984375 -0.140625
# ...         ...       ...       ...       ...
# 1915     59.843 -0.812500 -0.671875 -0.046875
# 1916     59.875 -0.734375 -0.687500 -0.046875
# 1917     59.906 -0.718750 -0.656250 -0.062500
# 1918     59.937 -0.734375 -0.656250 -0.078125
# 1919     59.968 -0.718750 -0.687500 -0.078125
#
# [1920 rows x 4 columns]
